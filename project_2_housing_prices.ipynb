# %% [markdown]
# ## Problem Statement

# %% [markdown]
# Welcome to DCH Designs. We help you find your perfect Fixer Upper, and take you through the design process that adds value to your future home in Ames, IA.

# %% [markdown]
# First we will predict values for a home we will first import our data and clean it up before making a model to predict houses.
#
# Then we will go through and find you a home, give you designs, and the new estimated value of the home.

# %% [markdown]
# ## Background
#
# Ames, Iowa is home to famed Iwoa State University.

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, cross_val_score

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df_train = pd.read_csv('./datasets/train.csv')
df_test = pd.read_csv('./datasets/test.csv')

# %% [markdown]
# ## Checking imported csv files
#
# **Training Shape:** 2051, 81
#
# **Training Columns:** See [Data Dictionary]('./code/data_dictionary.md')
#
# Id | PID | MS SubClass | MS Zoning | Lot Frontage | Lot Area | Street | Alley | Lot Shape | Land Contour | Utilities | Lot Config | Land Slope | Neighborhood | Condition 1 | Condition 2 | Bldg Type | House Style | Overall Qual | Overall Cond | Year Built | Year Remod/Add | Roof Style | Roof Matl | Exterior 1st | Exterior 2nd | Mas Vnr Type | Mas Vnr Area | Exter Qual | Exter Cond | Foundation | Bsmt Qual | Bsmt Cond | Bsmt Exposure | BsmtFin Type 1 | BsmtFin SF 1 | BsmtFin Type 2 | BsmtFin SF 2 | Bsmt Unf SF | Total Bsmt SF | Heating | Heating QC | Central Air | Electrical | 1st Flr SF | 2nd Flr SF | Low Qual Fin SF | Gr Liv Area | Bsmt Full Bath | Bsmt Half Bath | Full Bath | Half Bath | Bedroom AbvGr | Kitchen AbvGr | Kitchen Qual | TotRms AbvGrd | Functional | Fireplaces | Fireplace Qu | Garage Type | Garage Yr Blt | Garage Finish | Garage Cars | Garage Area | Garage Qual | Garage Cond | Paved Drive | Wood Deck SF | Open Porch SF | Enclosed Porch | 3Ssn Porch | Screen Porch | Pool Area | Pool QC | Fence | Misc Feature | Misc Val | Mo Sold | Yr Sold | Sale Type | SalePrice
#
#
# MS Subclass would need to be one hot encoded if used.
#
# MS Zoning would too... This is a column to quickly explore because most residences should be Zoned for residential. The main differences will be to see if higher density versus lower and medium density residential zoning has affects the price. This would need to be one-hot encoded and I might one-hot encode as different residential categories and 'other' depending on what a quick analysis finds.
#
# Lot Area should have a decently high correlation with price.
#
# Street and Alley would need to be one-hot encoded.
#
# Overall Quality and Overall Condition seem to be easy ordinal categories to see if there is a correlation.
#
# Sale condition would have an obvious affect on prices as short sales, foreclosures, off normal market sales between family members would most likely have lower prices than a typical sale.

# %%
df_train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
#  16  Bldg Type        2051 non-null   object
#  17  House Style      2051 non-null   object
#  18  Overall Qual     2051 non-null   int64
#  19  Overall Cond     2051 non-null   int64
#  20  Year Built       2051 non-null   int64
#  21  Year Remod/Add   2051 non-null   int64
#  22  Roof Style       2051 non-null   object
#  23  Roof Matl        2051 non-null   object
#  24  Exterior 1st     2051 non-null   object
#  25  Exterior 2nd     2051 non-null   object
#  26  Mas Vnr Type     2029 non-null   object
#  27  Mas Vnr Area     2029 non-null   float64
#  28  Exter Qual       2051 non-null   object
#  29  Exter Cond       2051 non-null   object
#  30  Foundation       2051 non-null   object
#  31  Bsmt Qual        1996 non-null   object
#  32  Bsmt Cond        1996 non-null   object
#  33  Bsmt Exposure    1993 non-null   object
#  34  BsmtFin Type 1   1996 non-null   object
#  35  BsmtFin SF 1     2050 non-null   float64
#  36  BsmtFin Type 2   1995 non-null   object
#  37  BsmtFin SF 2     2050 non-null   float64
#  38  Bsmt Unf SF      2050 non-null   float64
#  39  Total Bsmt SF    2050 non-null   float64
#  40  Heating          2051 non-null   object
#  41  Heating QC       2051 non-null   object
#  42  Central Air      2051 non-null   object
#  43  Electrical       2051 non-null   object
#  44  1st Flr SF       2051 non-null   int64
#  45  2nd Flr SF       2051 non-null   int64
#  46  Low Qual Fin SF  2051 non-null   int64
#  47  Gr Liv Area      2051 non-null   int64
#  48  Bsmt Full Bath   2049 non-null   float64
#  49  Bsmt Half Bath   2049 non-null   float64
#  50  Full Bath        2051 non-null   int64
#  51  Half Bath        2051 non-null   int64
#  52  Bedroom AbvGr    2051 non-null   int64
#  53  Kitchen AbvGr    2051 non-null   int64
#  54  Kitchen Qual     2051 non-null   object
#  55  TotRms AbvGrd    2051 non-null   int64
#  56  Functional       2051 non-null   object
#  57  Fireplaces       2051 non-null   int64
#  58  Fireplace Qu     1051 non-null   object
#  59  Garage Type      1938 non-null   object
#  60  Garage Yr Blt    1937 non-null   float64
#  61  Garage Finish    1937 non-null   object
#  62  Garage Cars      2050 non-null   float64
#  63  Garage Area      2050 non-null   float64
#  64  Garage Qual      1937 non-null   object
#  65  Garage Cond      1937 non-null   object
#  66  Paved Drive      2051 non-null   object
#  67  Wood Deck SF     2051 non-null   int64
#  68  Open Porch SF    2051 non-null   int64
#  69  Enclosed Porch   2051 non-null   int64
#  70  3Ssn Porch       2051 non-null   int64
#  71  Screen Porch     2051 non-null   int64
#  72  Pool Area        2051 non-null   int64
#  73  Pool QC          9 non-null      object
#  74  Fence            400 non-null    object
#  75  Misc Feature     65 non-null     object
#  76  Misc Val         2051 non-null   int64
#  77  Mo Sold          2051 non-null   int64
#  78  Yr Sold          2051 non-null   int64
#  79  Sale Type        2051 non-null   object
#  80  SalePrice        2051 non-null   int64
# dtypes: float64(11), int64(28), object(42)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Handling Nulls and Cleaning up Columns

# %% [markdown]
# There are a lot of columns and a lot of nulls in the set. List of columns with Null values are: **'Lot Frontage',
#  'Alley',
#  'Mas Vnr Type',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond',
#  'Pool QC',
#  'Fence',
#  'Misc Feature'**
#
#
#
# **Lot Frontage** has 330 null values. I will need to extrapolate values for these nulls if I decide to use **Lot Frontage** as a feature to make predictions.
#
# **Alley** has 1911 null values.
#
# **Mas Vnr Type** and **Mas Vnr Area** both have 22 nulls. I assume they do not have masonry veneers on the exterior. I will explore this further before deciding whether or not to use these columns as features.
#
# **Bas
#
# **Fireplace Quality** Homes without a basement would not have a quality. Categorey most likely will not be used as a feature.

# %%
#I used https://stackoverflow.com/questions/53137100/filter-pandas-dataframe-columns-with-null-data
# to create a list of columns that have nulls.

df_train.columns[df_train.isnull().any()].tolist()
# Out:
# ['Lot Frontage',
#  'Alley',
#  'Mas Vnr Type',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond',
#  'Pool QC',
#  'Fence',
#  'Misc Feature']

# %% [markdown]
# ### Lot Frontage

# %%
df_train[df_train['Lot Frontage'].isnull()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 7      145  535154050           20        RL           NaN     12160   Pave
# 8     1942  535353130           20        RL           NaN     15783   Pave
# 23      12  527165230           20        RL           NaN      7980   Pave
# 27    1534  909277040           50        RL           NaN     11700   Pave
# 31    2860  909276010           70        RL           NaN     11435   Pave
# 42     983  923275040           85        RL           NaN      9101   Pave
# 50    2511  533221080          160        FV           NaN      2998   Pave
# 59     997  527107010           60        RL           NaN     15038   Pave
# 62     230  905109170           20        RL           NaN     20062   Pave
# 71    1564  914453045           20        RL           NaN     23730   Pave
# 75    1360  903452025           30        RM           NaN      6291   Grvl
# 76    2723  905200380           30        RL           NaN     17529   Pave
# 90    1187  534127210           80        RL           NaN     11104   Pave
# 91    2154  907280090           60        RL           NaN     15295   Pave
# 94     124  534403410           80        RL           NaN     14112   Pave
# 106   2513  533223080          160        FV           NaN      2651   Pave
# 108   2309  526303060           20        RL           NaN     39384   Pave
# 111   1881  534252110           20        RL           NaN     12342   Pave
# 114    781  905228050           20        RL           NaN      9000   Pave
# 117   1168  533215020          120        FV           NaN      4765   Pave
# 118   1396  905226110          190        RL           NaN     10532   Pave
# 122   1826  532377140           20        RL           NaN      9945   Pave
# 125   1183  533350090           60        RL           NaN     24572   Pave
# 141   2438  528275080           60        RL           NaN      8658   Pave
# 142     89  532378110           20        RL           NaN      6897   Pave
# 148   2132  907192040           60        RL           NaN      8826   Pave
# 150    420  527455280           20        RL           NaN     10710   Pave
# 160   2067  905226050           30        RL           NaN     25339   Pave
# 161   2115  906403060           60        RL           NaN      8883   Pave
# 166   1320  902401010           50        RM           NaN      5700   Pave
# 169   1385  905108170           85        RL           NaN      7400   Pave
# 176   2432  528235050           60        RL           NaN      7861   Pave
# 177    777  905200220           20        RL           NaN     11616   Pave
# 192    988  924100040           20        RL           NaN      9819   Pave
# 200   2287  923228200          180        RM           NaN      1533   Pave
# 208   2421  528228325          120        RL           NaN      3196   Pave
# 210     24  527402200           20        RL           NaN     11241   Pave
# 221   2542  534275010           20        RL           NaN     10659   Pave
# 223   1393  905202230           20        RL           NaN     13500   Pave
# 226    973  923203190          120        RM           NaN      4500   Pave
# 236   1896  534425015           20        RL           NaN     22002   Pave
# 250   1105  528363020           60        RL           NaN     11929   Pave
# 253    265  907252120           20        RL           NaN     11423   Pave
# 262   1599  923227030           20        RL           NaN     17979   Pave
# 268   1863  534104090           60        FV           NaN      7050   Pave
# 284   1629  527165100           80        RL           NaN      9125   Pave
# 285   2073  905352010           20        RL           NaN     11075   Pave
# 290   2913  923226150           90        RL           NaN     11836   Pave
# 293   1470  907290250          120        RM           NaN      4426   Pave
# 295   1399  905351089          120        RL           NaN      2887   Pave
# 309    366  527182110          120        RL           NaN      5814   Pave
# 310   1462  907255060           20        RL           NaN     14860   Pave
# 311   2541  534250300           60        RL           NaN     14803   Pave
# 320   2041  903475040           50        RM           NaN     12358   Pave
# 327   1681  527452100          120        RL           NaN      4928   Pave
# 328   1773  528366050           20        RL           NaN     12692   Pave
# 333    748  903400220           75        RL           NaN     11888   Pave
# 334   2846  909131125          190        RH           NaN      7082   Pave
# 335    493  528292070           60        RL           NaN      8755   Pave
# 337   2283  923205025          190        RL           NaN     32463   Pave
# 339   1632  527182040          120        RL           NaN      3696   Pave
# 346   2724  905200490           80        RL           NaN     10246   Pave
# 370   2567  535103070           80        RL           NaN     12700   Pave
# 372   2493  532376250           20        RL           NaN      8638   Pave
# 375   1248  535302140           20        RL           NaN     12774   Pave
# 389    313  914478045           80        RL           NaN     12328   Pave
# 403    101  533221090          160        FV           NaN      2117   Pave
# 411   2176  908152070           20        RL           NaN      7917   Pave
# 416   2927  923276100           20        RL           NaN      8885   Pave
# 428    491  528292030           60        RL           NaN     15896   Pave
# 430   1848  533223050          160        FV           NaN      5105   Pave
# 435   1627  527163080           20        RL           NaN      9556   Pave
# 444   1665  527402240           60        RL           NaN      7472   Pave
# 446    581  534127130           20        RL           NaN     11717   Pave
# 452    774  905107310           85        RL           NaN      8014   Pave
# 453   1447  907202010           20        RL           NaN     12250   Pave
# 454    104  533223100          160        FV           NaN      2403   Pave
# 463   2257  916253320          120        RM           NaN      9763   Pave
# 469   2273  916477060           60        RL           NaN     11800   Pave
# 471   2116  906426060           50        RL           NaN    159000   Pave
# 482   2118  906475110           60        RL           NaN     12205   Pave
# 490    361  527164060           60        RL           NaN      9636   Pave
# 500   1202  534251280           60        RL           NaN      9130   Pave
# 504   1744  528228375          120        RL           NaN      3621   Pave
# 511   1082  528228405          120        RM           NaN      3940   Pave
# 514   2082  905475520           30        RL           NaN     11515   Pave
# 515   2344  527302080           50        RL           NaN     13837   Pave
# 531    966  916455070           20        RL           NaN      6853   Pave
# 541   1169  533215030          120        FV           NaN      4538   Pave
# 543   2503  533128030           60        RL           NaN     13346   Pave
# 545   1190  534129060           20        RL           NaN     15387   Pave
# 547   2677  903231190           50        RM           NaN      6240   Pave
# 549   2484  531478010           20        RH           NaN      8900   Pave
# 553    141  535152130           20        RL           NaN      8050   Pave
# 555   1366  903458110           50        RM           NaN      7920   Pave
# 557   1380  905104080           20        RL           NaN      7162   Pave
# 560    782  905229040           50        RL           NaN     11250   Pave
# 561    956  916176030           20        RL           NaN     14375   Pave
# 570   2248  914452090           85        RL           NaN     12150   Pave
# 572   2076  905377020           20        RL           NaN     22692   Pave
# 575    878  907290180          120        RM           NaN      4435   Pave
# 576   1548  910202100           30        RM           NaN      5890   Pave
# 593   1897  534425080           20        RL           NaN     14585   Pave
# 595    590  534151120           60        RL           NaN     13774   Pave
# 603   2489  532353030           20        RL           NaN      9240   Pave
# 626   1566  914467050           60        RL           NaN     11050   Pave
# 628   2577  535177100           20        RL           NaN      9610   Pave
# 639   1539  909425010           50        RL           NaN     15660   Pave
# 660   1358  903427090           70        RM           NaN      5100   Pave
# 661   1461  907255030           60        RL           NaN      9720   Pave
# 668   1158  533125080           60        RL           NaN      9205   Pave
# 671   1888  534278150           20        RL           NaN     14357   Pave
# 680    609  534402140           20        RL           NaN     11000   Pave
# 681   1990  902300020           70        RM           NaN     10337   Pave
# 691   2483  531452210           60        RL           NaN      9019   Pave
# 694   2072  905301050           20        RL           NaN    115149   Pave
# 716   1383  905107280           85        RL           NaN      7703   Pave
# 727   1565  914465060           20        RL           NaN     13265   Pave
# 731   2267  916455010           60        RL           NaN      9303   Pave
# 732   1389  905200510           20        RL           NaN      8544   Pave
# 733   2553  534430110           20        RL           NaN     11425   Pave
# 737    788  905402070           20        RL           NaN     15635   Pave
# 742   2899  916460070           20        RL           NaN      8098   Pave
# 745    315  916125360           20        RL           NaN     57200   Pave
# 747   1660  527359080           60        RL           NaN     12384   Pave
# 748   2353  527358090           85        RL           NaN      9927   Pave
# 750   1585  916460060           20        RL           NaN      7915   Pave
# 757   1264  535426260           20        RL           NaN     10920   Pave
# 760    954  914476380           80        RL           NaN      9947   Pave
# 764    123  534403360           80        RL           NaN     10600   Pave
# 765   1862  533352075           90        RL           NaN     18890   Pave
# 767   1758  528290060           60        RL           NaN      7750   Pave
# 781   1671  527425025           20        RL           NaN     17199   Pave
# 811   1448  907202160           80        RL           NaN     10970   Pave
# 818   2147  907252190           20        RL           NaN     11354   Pave
# 827   2495  532378070           20        RL           NaN     13526   Pave
# 830    396  527404020           20        RL           NaN      7830   Pave
# 835   2454  528366040           60        RL           NaN     12585   Pave
# 849    111  534129040           20        RL           NaN     10456   Pave
# 850   1207  534277070           20        RL           NaN      8475   Pave
# 864   2791  907252050           60        RL           NaN      9930   Pave
# 871    226  905107110           90        RL           NaN      7424   Pave
# 875   1265  535426350           20        RL           NaN     12929   Pave
# 876    559  532376070           20        RL           NaN      9316   Pave
# 877   1203  534252090           85        RL           NaN     12122   Pave
# 913   2230  909475070           20        RL           NaN     32668   Pave
# 919    730  903201020           30        RL           NaN      6615   Pave
# 921   2793  907255010           20        RL           NaN     11088   Pave
# 926   1038  527425035           20        RL           NaN     12735   Pave
# 927   1763  528326060           60        RL           NaN     11000   Pave
# 938   2437  528275060           60        RL           NaN      8121   Pave
# 1977   498  528344040           60        RL           NaN     16545   Pave
# 1998   374  527326150           20        RL           NaN     16635   Pave
# 2001  1422  906223140           60        RL           NaN     14171   Pave
# 2003  1151  532353050           20        RL           NaN     12968   Pave
# 2008  1871  534175010           90        RL           NaN     11500   Pave
# 2015  2253  914476330           20        RL           NaN      9928   Pave
# 2016   560  532376110           20        RL           NaN      7791   Pave
# 2022  2872  909475020           20        RL           NaN     16381   Pave
# 2028  2526  534127190           20        RL           NaN     20781   Pave
# 2031    25  527402250           20        RL           NaN     12537   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 0      NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 7      NaN       IR1          Lvl    AllPub     Inside        Gtl
# 8      NaN       Reg          Lvl    AllPub     Inside        Gtl
# 23     NaN       IR1          Lvl    AllPub     Inside        Gtl
# 27    Grvl       IR1          HLS    AllPub     Inside        Mod
# 31     NaN       IR1          HLS    AllPub     Corner        Mod
# 42     NaN       IR1          Lvl    AllPub     Corner        Gtl
# 50     NaN       Reg          Lvl    AllPub     Inside        Gtl
# 59     NaN       IR2          Lvl    AllPub     Corner        Gtl
# 62     NaN       IR1          Low    AllPub     Inside        Mod
# 71     NaN       IR2          Lvl    AllPub     Inside        Gtl
# 75     NaN       IR1          Lvl    AllPub     Inside        Gtl
# 76     NaN       Reg          Lvl    AllPub     Inside        Gtl
# 90     NaN       IR1          Lvl    AllPub     Inside        Gtl
# 91     NaN       IR3          Lvl    AllPub     Corner        Gtl
# 94     NaN       IR1          Lvl    AllPub     Corner        Gtl
# 106    NaN       Reg          Lvl    AllPub        FR2        Gtl
# 108    NaN       IR1          Low    AllPub    CulDSac        Sev
# 111    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 114    NaN       Reg          Lvl    AllPub     Corner        Gtl
# 117    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 118    NaN       Reg          Lvl    AllPub     Corner        Gtl
# 122    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 125    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 141    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 142    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 148    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 150    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 160    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 161    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 166    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 169    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 176    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 177    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 192    NaN       IR1          Lvl    AllPub     Inside        Mod
# 200    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 208    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 210    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 221    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 223    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 226    NaN       Reg          Lvl    AllPub        FR2        Gtl
# 236    NaN       Reg          Lvl    AllPub     Corner        Gtl
# 250    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 253    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 262    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 268    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 284    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 285    NaN       Reg          Lvl    AllPub     Corner        Gtl
# 290    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 293    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 295    NaN       Reg          HLS    AllPub     Inside        Gtl
# 309    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 310    NaN       IR2          Lvl    AllPub    CulDSac        Gtl
# 311    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 320    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 327    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 328    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 333   Pave       IR1          Bnk    AllPub     Inside        Gtl
# 334    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 335    NaN       IR1          Lvl    AllPub        FR2        Gtl
# 337    NaN       Reg          Low    AllPub     Inside        Mod
# 339    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 346    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 370    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 372    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 375    NaN       Reg          Lvl    AllPub     Inside        Sev
# 389    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 403    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 411    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 416    NaN       IR1          Low    AllPub     Inside        Mod
# 428    NaN       IR2          Lvl    AllPub    CulDSac        Gtl
# 430    NaN       IR2          Lvl    AllPub        FR2        Gtl
# 435    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 444    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 446    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 452    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 453    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 454    NaN       IR1          Lvl    AllPub        FR2        Gtl
# 463    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 469    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 471    NaN       IR2          Low    AllPub    CulDSac        Sev
# 482    NaN       IR1          Low    AllPub     Inside        Gtl
# 490    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 500    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 504    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 511    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 514    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 515    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 531    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 541    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 543    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 545    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 547    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 549    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 553    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 555   Grvl       IR1          Lvl    AllPub     Inside        Gtl
# 557    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 560    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 561    NaN       IR1          Lvl    NoSeWa    CulDSac        Gtl
# 570    NaN       IR1          Bnk    AllPub    CulDSac        Gtl
# 572    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 575    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 576    NaN       Reg          Lvl    AllPub     Corner        Gtl
# 593    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 595    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 603    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 626    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 628    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 639    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 660   Grvl       Reg          Lvl    AllPub     Inside        Gtl
# 661    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 668    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 671    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 680    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 681   Pave       IR1          Lvl    AllPub     Inside        Gtl
# 691    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 694    NaN       IR2          Low    AllPub    CulDSac        Sev
# 716    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 727    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 731    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 732    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 733    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 737    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 742    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 745    NaN       IR1          Bnk    AllPub     Inside        Sev
# 747    NaN       Reg          Lvl    AllPub    CulDSac        Gtl
# 748    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 750    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 757    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 760    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 764   Pave       IR1          Lvl    AllPub     Inside        Gtl
# 765    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 767    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 781    NaN       Reg          Lvl    AllPub        FR2        Gtl
# 811    NaN       IR1          Low    AllPub     Inside        Mod
# 818    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 827    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 830    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 835    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 849    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 850    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 864    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 871    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 875    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 876    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 877    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 913    NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 919    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 921    NaN       Reg          Lvl    AllPub     Corner        Gtl
# 926    NaN       IR1          Lvl    AllPub        FR2        Gtl
# 927    NaN       Reg          Lvl    AllPub        FR2        Gtl
# 938    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 941    NaN       IR3          Lvl    AllPub     Corner        Gtl
# 944    NaN       IR1          Lvl    AllPub     Corner        Gtl
# 950    NaN       Reg          Lvl    AllPub     Inside        Gtl
# 957    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 966    NaN       IR1          Low    AllPub     Corner        Mod
# 971    NaN       IR1          Low    AllPub    CulDSac        Mod
# 980    NaN       Reg          Bnk    AllPub     Corner        Gtl
# 982    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1000   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1004   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1007   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1009   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1017   NaN       IR1          Bnk    AllPub     Inside        Gtl
# 1030   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1042  Grvl       Reg          Lvl    AllPub     Inside        Gtl
# 1048   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1049   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1052   NaN       IR1          Low    AllPub    CulDSac        Mod
# 1066   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1067   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1070   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1079   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1090   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1105   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1113   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1114   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1117   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1121   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1125   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1142   NaN       IR1          Low    AllPub     Inside        Gtl
# 1152   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1165   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1167   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1173   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1181   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1183   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1185   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1203   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1208   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1211   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1212   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1216   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1223   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1233   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1237   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1240   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1243   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1244   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1249   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1259   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1264   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1271   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1275   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1277   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1288   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1293   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1303   NaN       IR1          Bnk    AllPub     Inside        Gtl
# 1306   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1311   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1313   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1316   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1333   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1336   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1338   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1342   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1357   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1370   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1372   NaN       IR1          Low    AllPub     Inside        Sev
# 1387   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1393   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1397   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1398   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1414   NaN       IR1          Low    AllPub    CulDSac        Mod
# 1420   NaN       IR1          Bnk    AllPub     Corner        Gtl
# 1426   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1427   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1430   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1436  Pave       IR1          Lvl    AllPub     Inside        Gtl
# 1438   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1450   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1453   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1458   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1469   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1475   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1491   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1492   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1495   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1508   NaN       IR1          Bnk    AllPub     Corner        Gtl
# 1513   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1514   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1515   NaN       Reg          HLS    AllPub     Inside        Gtl
# 1521   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1523   NaN       Reg          Bnk    AllPub     Inside        Gtl
# 1527   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1530   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1533   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1536   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1538   NaN       Reg          Lvl    AllPub     Corner        Gtl
# 1540   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1548   NaN       IR2          Lvl    AllPub     Inside        Gtl
# 1565   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1566   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1567   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1576   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1582   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1583   NaN       IR1          Lvl    AllPub        FR3        Gtl
# 1587   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1597   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1605   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1606   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1608   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1610   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1611   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1616   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1623   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1625   NaN       IR1          HLS    AllPub     Inside        Gtl
# 1631   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1660   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1664   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1666   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1668   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1690   NaN       Reg          Lvl    AllPub     Inside        Gtl
# 1695   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1696   NaN       IR1          Low    AllPub    CulDSac        Gtl
# 1702   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1721   NaN       IR2          Lvl    AllPub     Corner        Gtl
# 1726   NaN       IR1          Low    AllPub     Inside        Mod
# 1735   NaN       IR3          Lvl    AllPub     Inside        Gtl
# 1736   NaN       Reg          Lvl    AllPub     Corner        Gtl
# 1740   NaN       IR1          Lvl    AllPub     Corner        Gtl
# 1741   NaN       IR2          Lvl    AllPub     Inside        Gtl
# 1742   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1745   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1757   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1765   NaN       Reg          Lvl    AllPub     Corner        Gtl
# 1770   NaN       IR1          Lvl    AllPub    CulDSac        Gtl
# 1783   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1784   NaN       IR1          Lvl    AllPub     Inside        Gtl
# 
NaN         0        3
#
#       Yr Sold Sale Type  SalePrice
# 0        2010       WD      130500
# 7        2010       COD     142000
# 8        2007       WD      112500
# 23       2010       WD      185000
# 27       2008       WD      198000
# 31       2006       WD      230000
# 42       2009       WD      165500
# 50       2006       WD      166000
# 59       2008       WD      173000
# 62       2010       WD      270000
# 71       2008       WD      300000
# 75       2008       WD       93850
# 76       2006       WD      105000
# 90       2008       WD      183000
# 91       2007       WD      211000
# 94       2010       WD      180500
# 106      2006       WD      165000
# 108      2006       WD      252000
# 111      2007       WD      139900
# 114      2009       WD       63900
# 117      2008       WD      300000
# 118      2008       WD      145000
# 122      2007       WD      128500
# 125      2008       WD      150000
# 141      2006       WD      215000
# 142      2010       WD      127000
# 148      2007       WD      217500
# 150      2009       WD      148800
# 160      2007       WD      112000
# 161      2007       WD      207000
# 166      2008       WD      116900
# 169      2008       WD      152000
# 176      2006       WD      183200
# 177      2009       WD      139000
# 192      2009       WD      196000
# 200      2007       WD      106500
# 208      2006       WD      234000
# 210      2010       WD      149000
# 221      2006       COD     136500
# 223      2008       WD      235000
# 226      2009       WD      165000
# 236      2007       WD      200000
# 250      2008       WD      290000
# 253      2010       WD      272000
# 262      2008       WD      152500
# 268      2007       WD      226000
# 284      2007       WD      163900
# 285      2007       WD      182000
# 290      2006       WD      146500
# 293      2008       WD      145000
# 295      2008       WD      173000
# 309      2009       COD     187500
# 310      2008       WD      300000
# 311      2006       WD      190000
# 320      2007       WD      128500
# 327      2007       WD      128000
# 328      2007       WD      430000
# 333      2009       WD      214500
# 334      2006       WD      160000
# 335      2009       WD      214000
# 337      2007       WD      168000
# 339      2007       WD      170000
# 346      2006       WD      145000
# 370      2006       WD      172000
# 372      2006       WD      133500
# 375      2008       WD      130000
# 389      2010       WD      169900
# 403      2010       WD      177500
# 411      2007       WD      148000
# 416      2006       WD      131000
# 428      2009       WD      245000
# 430      2007       WD      148800
# 435      2007       WD      160000
# 444      2007       WD      184000
# 446      2009       WD      185000
# 452      2009       WD      149900
# 453      2008       WD      158000
# 454      2010       WD      147110
# 463      2007       WD      330000
# 469      2007       WD      279900
# 471      2007       WD      277000
# 482      2007       WD      187500
# 490      2009       WD      178000
# 500      2008       WD      173000
# 504      2007       WD      226500
# 511      2008       WD      219990
# 514      2007       WD       80000
# 515      2006       WD      229000
# 531      2009       WD      220000
# 541      2008       WD      285000
# 543      2006       WD      268000
# 545      2008       WD      215000
# 547      2006       WD      115000
# 549      2006       WD      107000
# 553      2010       WD      136000
# 555      2008       WD       89500
# 557      2008       WD      109900
# 560      2009       WD      161500
# 561      2009       COD     137500
# 570      2007       WD      183500
# 572      2007       COD     130000
# 575      2009       WD      144000
# 576      2008       WD      120500
# 593      2007       WD      181900
# 595      2009       WD      230000
# 603      2006       WD      144000
# 626      2008       WD      213000
# 628      2006       WD      162000
# 639      2008       WD      311500
# 660      2008       WD      161000
# 661      2008       WD      274000
# 668      2008       WD      290000
# 671      2007       CWD     140500
# 680      2009       WD      154000
# 681      2007       WD      184900
# 691      2006       WD      150000
# 694      2007       WD      302000
# 716      2008       WD      153000
# 727      2008       WD      271000
# 731      2007       WD      204000
# 732      2008       WD      149350
# 733      2006       WD      137000
# 737      2009       WD      122000
# 742      2006       WD      202000
# 745      2010       WD      160000
# 747      2007       WD      197900
# 748      2006       WD      172000
# 750      2008       WD      195000
# 757      2008       WD      157000
# 760      2009       WD      173000
# 764      2010       COD     136300
# 765      2007       WD      190000
# 767      2007       WD      162000
# 781      2007       WD      128000
# 811      2008       WD      147000
# 818      2007       WD      270000
# 827      2006       WD      137000
# 830      2009       COD     128000
# 835      2006       WD      315000
# 849      2010       WD      218500
# 850      2008       WD      135750
# 864      2006       WD      222000
# 871      2010       WD      160250
# 875      2008       WD      148000
# 876      2009       Oth     124100
# 877      2008       WD      178400
# 913      2007       WD      200624
# 919      2009       WD      149000
# 921      2006       WD      220000
# 926      2008       COD     111250
# 927      2007       WD      248000
# 938      2006       WD      172400
# 941      2008       WD      260000
# 944      2009       COD     158000
# 950      2008       WD      115000
# 957      2009       WD      185750
# 966      2007       WD      188000
# 971      2010       WD      230000
# 980      2007       COD     217000
# 982      2009       WD      148500
# 1000     2009       COD     190000
# 1004     2007       WD      302000
# 1007     2007       WD      103000
# 1009     2007       WD      171000
# 1017     2009       WD      177500
# 1030     2007       WD      181000
# 1042     2008       WD      120000
# 1048     2008       WD      144000
# 1049     2007       WD      141000
# 1052     2008       WD      256000
# 1066     2010     ConLD     170000
# 1067     2007       WD      168000
# 1070     2010       WD      222500
# 1079     2007       WD      126000
# 1090     2010       COD     244400
# 1105     2006       WD      183500
# 1113     2008       WD      188000
# 1114     2007       WD      175000
# 1117     2007       WD      466500
# 1121     2006       WD      137000
# 1125     2006       WD       87500
# 1142     2009       WD      275000
# 1152     2007       CWD     215000
# 1165     2008       WD      162500
# 1167     2008       WD      133000
# 1173     2009       WD      176000
# 1181     2006       WD      172500
# 1183     2009       WD      140000
# 1185     2008       WD      179200
# 1203     2007       WD      160000
# 1208     2008       WD      120000
# 1211     2006       WD      230000
# 1212     2007       WD      140000
# 1216     2008       WD      124000
# 1223     2006       WD      246990
# 1233     2008       WD      181900
# 1237     2009       WD      236500
# 1240     2008       WD      213000
# 1243     2008       COD     287000
# 1244     2009       WD      257500
# 1249     2006       WD      274970
# 1259     2009       WD      313000
# 1264     2007       WD      195000
# 1271     2007       WD      275000
# 1275     2009       WD      219500
# 1277     2009       WD      135000
# 1288     2010       WD      143000
# 1293     2008       WD      292500
# 1303     2007       WD      300000
# 1306     2007       WD      165500
# 1311     2006       WD      215000
# 1313     2010       WD      212000
# 1316     2008       WD      188000
# 1333     2007       WD      156000
# 1336     2009       WD      157500
# 1338     2006       WD      193000
# 1342     2007       New     281500
# 1357     2009       WD      213000
# 1370     2009       COD     112000
# 1372     2009       WD       61000
# 1387     2009       WD      139600
# 1393     2008       WD      299800
# 1397     2008       WD      272000
# 1398     2009       WD      173000
# 1414     2006       WD      275000
# 1420     2007       WD      198000
# 1426     2009     ConLI     200000
# 1427     2006       WD      119000
# 1430     2008       WD      205000
# 1436     2007       WD      301000
# 1438     2006       WD      171750
# 1450     2007       WD      211000
# 1453     2009       WD      150000
# 1458     2007       WD      216000
# 1469     2010       WD      143750
# 1475     2006       WD      126000
# 1491     2008       WD      141000
# 1492     2006       WD      167000
# 1495     2010       WD      122000
# 1508     2008       WD      108000
# 1513     2007       WD      108000
# 1514     2009       WD      122000
# 1515     2006       WD      148400
# 1521     2008       WD      147000
# 1523     2009       WD      315000
# 1527     2007       WD      177000
# 1530     2006       WD      158000
# 1533     2010       WD      216000
# 1536     2006       WD      160500
# 1538     2008       WD      148000
# 1540     2006       WD      310000
# 1548     2007       WD      170000
# 1565     2007       WD      180500
# 1566     2009       WD      269500
# 1567     2007       WD      225000
# 1576     2008       WD      175000
# 1582     2006       WD      250000
# 1583     2008       WD      306000
# 1587     2010       WD      205000
# 1597     2006       WD      165000
# 1605     2009       WD      269500
# 1606     2008       WD      176000
# 1608     2009       WD      184100
# 1610     2009       WD      208000
# 1611     2009       WD      140000
# 1616     2009       WD      140000
# 1623     2006       WD      149900
# 1625     2006       WD      277500
# 1631     2007       WD      125500
# 1660     2008       WD      143195
# 1664     2007       WD      168000
# 1666     2007       WD      143250
# 1668     2010       WD      205000
# 1690     2009       WD      261500
# 1695     2007       WD      129000
# 1696     2008       WD      224000
# 1702     2008       WD      215700
# 1721     2008       WD      225000
# 1726     2006       WD      250764
# 1735     2007       WD      163500
# 1736     2006       WD      100000
# 1740     2010       WD      162000
# 1741     2010       New     222000
# 1742     2009       WD      178000
# 1745     2009       WD      236000
# 1757     2006       WD      129200
# 1765     2007       WD      169500
# 1770     2010       COD     114000
# 1783     2006       WD      124000
# 1784     2010       WD      121500
# 1791     2009       WD      205000
# 1803     2007       WD      135000
# 1807     2006       WD      279000
# 1813     2006       WD      225000
# 1816     2007       WD      277000
# 1822     2009       WD      177500
# 1832     2009       WD      225000
# 1843     2007       WD      240000
# 1858     2006       WD      275000
# 1865     2007       WD      123000
# 1866     2008       WD      291000
# 1869     2009       WD      177625
# 1873     2009       WD      168500
# 1874     2006       WD      170000
# 1882     2007       WD      219500
# 1910     2009       WD      270000
# 1918     2007       WD      220000
# 1924     2009       WD      263550
# 1925     2007       WD      182900
# 1926     2009       WD      222000
# 1933     2006       WD      169000
# 1941     2010       WD      216500
# 1943     2007       WD      134500
# 1947     2009       WD      275000
# 1949     2009       WD      244000
# 1956     2009       WD      187500
# 1960     2006       WD      210900
# 1963     2009       WD      154000
# 1967     2009       WD      204000
# 1977     2009       WD      340000
# 1998     2009       WD      215000
# 2001     2008       WD      225000
# 2003     2008       WD      144000
# 2008     2007       WD      136905
# 2015     2007       WD      210000
# 2016     2009       WD      129000
# 2022     2006       WD      223000
# 2028     2006       WD      262500
# 2031     2010       WD      149900
# 2047     2009       WD       82500

# %%
df_train['Lot Shape'].value_counts()
# Out:
# Reg    1295
# IR1     692
# IR2      55
# IR3       9
# Name: Lot Shape, dtype: int64

# %%
df_train.groupby('Lot Shape')['Lot Frontage', 'Lot Area'].agg(['count', 'mean', 'median'])
# Out:
# <ipython-input-8-3128da55a1b7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_train.groupby('Lot Shape')['Lot Frontage', 'Lot Area'].agg(['count', 'mean', 'median'])
#           Lot Frontage                    Lot Area
#                  count        mean median    count          mean   median
# Lot Shape
# IR1                469   74.582090   73.0      692  11470.709538  10456.5
# IR2                 36   59.416667   51.0       55  19995.454545  13682.0
# IR3                  6  115.666667   78.0        9  21102.222222  15295.0
# Reg               1210   66.968595   65.0     1295   8815.707336   8773.0

# %% [markdown]
# I am checking below if there is correlation between Lot Shape and Lot Frontage, or if it primarily depends on the Lot Area.

# %%
df_train_lotshape = pd.get_dummies(data = df_train, columns = ['Lot Shape'])

# %%
df_train_lotshape.corr()['Lot Frontage']
# Out:
# Id                -0.024967
# PID               -0.091291
# MS SubClass       -0.389790
# Lot Frontage       1.000000
# Lot Area           0.574024
# Overall Qual       0.194808
# Overall Cond      -0.054455
# Year Built         0.109504
# Year Remod/Add     0.085052
# Mas Vnr Area       0.218218
# BsmtFin SF 1       0.214178
# BsmtFin SF 2       0.036740
# Bsmt Unf SF        0.127605
# Total Bsmt SF      0.356584
# 1st Flr SF         0.463900
# 2nd Flr SF         0.013700
# Low Qual Fin SF   -0.000300
# Gr Liv Area        0.383856
# Bsmt Full Bath     0.111441
# Bsmt Half Bath    -0.030858
# Full Bath          0.152812
# Half Bath          0.035842
# Bedroom AbvGr      0.220414
# Kitchen AbvGr      0.015856
# TotRms AbvGrd      0.362704
# Fireplaces         0.253456
# Garage Yr Blt      0.067865
# Garage Cars        0.297143
# Garage Area        0.358457
# Wood Deck SF       0.115180
# Open Porch SF      0.184958
# Enclosed Porch    -0.003302
# 3Ssn Porch         0.031855
# Screen Porch       0.074819
# Pool Area          0.156575
# Misc Val           0.051676
# Mo Sold           -0.017389
# Yr Sold            0.009112
# SalePrice          0.341842
# Lot Shape_IR1      0.145469
# Lot Shape_IR2     -0.060585
# Lot Shape_IR3      0.118561
# Lot Shape_Reg     -0.138079
# Name: Lot Frontage, dtype: float64

# %% [raw]
# It looks like there is only a max of about 0.15 correlation with the different Lot Shapes and the Lot Frontage, so I will instead use Lot Area as information to help fill in values for Lot Frontage.

# %%
df_train['lot_area_frontage'] = df_train['Lot Frontage'] / df_train['Lot Area']

# %%
l_a_f_mean = df_train['Lot Area'] * df_train['lot_area_frontage'].mean()

# %%
df_train['Lot Frontage'].fillna(l_a_f_mean, inplace = True)

# %%
df_train['Lot Frontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Alley Column

# %%
df_train['Alley'].isnull().mean()
# Out:
# 0.931740614334471

# %%
df_train['Alley'].value_counts()
# Out:
# Grvl    85
# Pave    55
# Name: Alley, dtype: int64

# %% [markdown]
# The Column 'Alley' has 85 homes with Gravel and 55 with Pavel alleys. The remainder I assume do not have alleys. Since 93% of homes do **not** have an alley I will probably not use the column as a feature.

# %% [markdown]
# ### Mas Vnr Type & Mas Ven Area
#
# A majority of homes do not have masonry veneer, so I will fill null values with 'None.'

# %%
df_train['Mas Vnr Type'].value_counts()
# Out:
# None       1218
# BrkFace     630
# Stone       168
# BrkCmn       13
# Name: Mas Vnr Type, dtype: int64

# %%
df_train['Mas Vnr Type'].fillna('None', inplace = True)

# %%
df_train['Mas Vnr Area'].fillna(0, inplace = True)

# %% [markdown]
# ### Bsmt Qual

# %%
df_train['Bsmt Qual'].value_counts()
# Out:
# TA    887
# Gd    864
# Ex    184
# Fa     60
# Po      1
# Name: Bsmt Qual, dtype: int64

# %%
df_train['Bsmt Qual'].fillna('None', inplace = True)

# %%
qual_dict = {np.nan : 0, 'None' : 0, 'Po' : 1, 'Fa' : 2, 'Ta' : 3, 'Gd' : 4, 'TA' : 5}

# %%
df_train['Bsmt Qual'].isna().sum()
# Out:
# 0

# %%
df_train['Bsmt Qual'] = df_train['Bsmt Qual'].map(qual_dict)

# %%
df_train['Bsmt Qual'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Bsmt Cond

# %%
df_train['Bsmt Cond'].value_counts()
# Out:
# TA    1834
# Gd      89
# Fa      65
# Po       5
# Ex       3
# Name: Bsmt Cond, dtype: int64

# %%
df_train['Bsmt Cond'].isna().sum()
# Out:
# 55

# %%
df_train['Bsmt Cond'].fillna('None', inplace = True)

# %%
df_train['Bsmt Cond'] = df_train['Bsmt Cond'].map(qual_dict)

# %%
df_train['Bsmt Cond'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Bsmt Exposure

# %%
df_train['Bsmt Exposure'].value_counts()
# Out:
# No    1339
# Av     288
# Gd     203
# Mn     163
# Name: Bsmt Exposure, dtype: int64

# %%
df_train['Bsmt Exposure'].isnull().sum()
# Out:
# 58

# %%
df_train['Bsmt Exposure'].fillna('None', inplace = True)

# %%
bsmt_dict = {'No' : 0, 'None' : 0, 'Mn' : 1, 'Av' : 2, 'Gd' : 3}

# %%
df_train['Bsmt Exposure'] = df_train['Bsmt Exposure'].map(bsmt_dict)

# %% [markdown]
# ### Bsmt Fin Type 1

# %%
df_train['BsmtFin Type 1'].value_counts()
# Out:
# GLQ    615
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# Name: BsmtFin Type 1, dtype: int64

# %%
df_train['BsmtFin Type 1'].isnull().sum()
# Out:
# 55

# %%
df_train['BsmtFin Type 1'].fillna('None', inplace = True)

# %%
bsmt_fin_dict = {'None' : 0,'Unf' : 0, 'LwQ' : 1, 'Rec' : 2, 'BLQ' : 3, 'ALQ' : 4, 'GLQ' : 5}

# %%
df_train['BsmtFin Type 1'] = df_train['BsmtFin Type 1'].map(bsmt_fin_dict)

# %% [markdown]
# ### BsmtFin SF 1

# %%
df_train['BsmtFin SF 1'].value_counts()
# Out:
# 0.0       657
# 24.0       17
# 16.0       10
# 300.0       7
# 384.0       7
# 20.0        7
# 700.0       6
# 624.0       6
# 456.0       6
# 360.0       6
# 312.0       6
# 368.0       6
# 1200.0      5
# 648.0       5
# 330.0       5
# 288.0       5
# 553.0       5
# 432.0       5
# 637.0       5
# 686.0       5
# 625.0       5
# 120.0       5
# 276.0       5
# 841.0       4
# 336.0       4
# 495.0       4
# 904.0       4
# 507.0       4
# 500.0       4
# 528.0       4
# 476.0       4
# 600.0       4
# 247.0       4
# 758.0       4
# 1218.0      4
# 319.0       4
# 784.0       4
# 28.0        4
# 252.0       4
# 851.0       4
# 732.0       4
# 450.0       4
# 410.0       4
# 468.0       4
# 425.0       4
# 547.0       4
# 338.0       4
# 836.0       4
# 350.0       4
# 549.0       4
# 375.0       4
# 104.0       4
# 56.0        4
# 588.0       4
# 626.0       4
# 510.0       4
# 544.0       4
# 492.0       3
# 915.0       3
# 560.0       3
# 602.0       3
# 776.0       3
# 594.0       3
# 353.0       3
# 437.0       3
# 299.0       3
# 240.0       3
# 527.0       3
# 644.0       3
# 786.0       3
# 280.0       3
# 532.0       3
# 138.0       3
# 690.0       3
# 442.0       3
# 408.0       3
# 778.0       3
# 728.0       3
# 264.0       3
# 697.0       3
# 504.0       3
# 1309.0      3
# 234.0       3
# 655.0       3
# 569.0       3
# 1153.0      3
# 1173.0      3
# 578.0       3
# 788.0       3
# 685.0       3
# 1036.0      3
# 565.0       3
# 390.0       3
# 616.0       3
# 1116.0      3
# 533.0       3
# 747.0       3
# 548.0       3
# 210.0       3
# 986.0       3
# 603.0       3
# 872.0       3
# 1023.0      3
# 522.0       3
# 550.0       3
# 775.0       3
# 189.0       3
# 1201.0      3
# 674.0       3
# 516.0       3
# 781.0       3
# 144.0       3
# 936.0       3
# 612.0       3
# 428.0       3
# 1059.0      3
# 964.0       3
# 780.0       3
# 494.0       3
# 659.0       3
# 490.0       3
# 400.0       3
# 80.0        3
# 672.0       3
# 403.0       3
# 130.0       3
# 762.0       3
# 570.0       3
# 988.0       3
# 36.0        3
# 704.0       3
# 60.0        3
# 1148.0      3
# 967.0       2
# 654.0       2
# 454.0       2
# 531.0       2
# 462.0       2
# 619.0       2
# 705.0       2
# 923.0       2
# 894.0       2
# 486.0       2
# 275.0       2
# 285.0       2
# 1246.0      2
# 506.0       2
# 821.0       2
# 266.0       2
# 738.0       2
# 740.0       2
# 1078.0      2
# 813.0       2
# 716.0       2
# 315.0       2
# 790.0       2
# 294.0       2
# 695.0       2
# 980.0       2
# 419.0       2
# 351.0       2
# 326.0       2
# 820.0       2
# 812.0       2
# 902.0       2
# 298.0       2
# 290.0       2
# 305.0       2
# 639.0       2
# 441.0       2
# 358.0       2
# 662.0       2
# 641.0       2
# 803.0       2
# 633.0       2
# 1400.0      2
# 1039.0      2
# 706.0       2
# 846.0       2
# 321.0       2
# 1018.0      2
# 769.0       2
# 920.0       2
# 755.0       2
# 606.0       2
# 1110.0      2
# 1373.0      2
# 457.0       2
# 226.0       2
# 708.0       2
# 156.0       2
# 386.0       2
# 1234.0      2
# 111.0       2
# 534.0       2
# 453.0       2
# 668.0       2
# 535.0       2
# 828.0       2
# 274.0       2
# 292.0       2
# 1056.0      2
# 81.0        2
# 819.0       2
# 770.0       2
# 182.0       2
# 630.0       2
# 682.0       2
# 513.0       2
# 340.0       2
# 228.0       2
# 1219.0      2
# 379.0       2
# 1518.0      2
# 505.0       2
# 574.0       2
# 941.0       2
# 417.0       2
# 720.0       2
# 297.0       2
# 209.0       2
# 656.0       2
# 150.0       2
# 1369.0      2
# 580.0       2
# 1016.0      2
# 789.0       2
# 196.0       2
# 250.0       2
# 773.0       2
# 976.0       2
# 110.0       2
# 929.0       2
# 162.0       2
# 816.0       2
# 1000.0      2
# 660.0       2
# 282.0       2
# 1300.0      2
# 717.0       2
# 119.0       2
# 930.0       2
# 133.0       2
# 638.0       2
# 744.0       2
# 681.0       2
# 273.0       2
# 901.0       2
# 956.0       2
# 52.0        2
# 348.0       2
# 458.0       2
# 246.0       2
# 1198.0      2
# 57.0        2
# 651.0       2
# 745.0       2
# 699.0       2
# 1386.0      2
# 48.0        2
# 791.0       2
# 1088.0      2
# 1005.0      2
# 416.0       2
# 617.0       2
# 1430.0      2
# 342.0       2
# 680.0       2
# 622.0       2
# 444.0       2
# 257.0       2
# 50.0        2
# 392.0       2
# 1232.0      2
# 666.0       2
# 435.0       2
# 114.0       2
# 903.0       2
# 371.0       2
# 1567.0      2
# 198.0       2
# 1004.0      2
# 856.0       2
# 925.0       2
# 460.0       2
# 361.0       2
# 1206.0      2
# 1040.0      2
# 259.0       2
# 568.0       2
# 308.0       2
# 679.0       2
# 621.0       2
# 1032.0      2
# 176.0       2
# 1288.0      2
# 546.0       2
# 566.0       2
# 485.0       2
# 748.0       2
# 785.0       2
# 727.0       2
# 420.0       2
# 397.0       2
# 864.0       2
# 673.0       2
# 1084.0      2
# 378.0       2
# 1196.0      2
# 733.0       2
# 539.0       2
# 341.0       2
# 503.0       2
# 168.0       2
# 595.0       2
# 741.0       2
# 678.0       2
# 385.0       2
# 40.0        2
# 448.0       2
# 311.0       2
# 787.0       2
# 734.0       2
# 116.0       2
# 608.0       2
# 767.0       2
# 945.0       2
# 599.0       2
# 663.0       2
# 832.0       2
# 381.0       2
# 774.0       2
# 1476.0      2
# 658.0       2
# 737.0       2
# 380.0       1
# 208.0       1
# 896.0       1
# 512.0       1
# 1152.0      1
# 576.0       1
# 230.0       1
# 736.0       1
# 241.0       1
# 132.0       1
# 520.0       1
# 1728.0      1
# 222.0       1
# 180.0       1
# 200.0       1
# 509.0       1
# 1280.0      1
# 760.0       1
# 248.0       1
# 1337.0      1
# 876.0       1
# 35.0        1
# 260.0       1
# 464.0       1
# 1048.0      1
# 808.0       1
# 100.0       1
# 4010.0      1
# 960.0       1
# 216.0       1
# 1024.0      1
# 42.0        1
# 837.0       1
# 607.0       1
# 759.0       1
# 1531.0      1
# 2085.0      1
# 1346.0      1
# 415.0       1
# 1383.0      1
# 64.0        1
# 475.0       1
# 1002.0      1
# 471.0       1
# 1312.0      1
# 838.0       1
# 840.0       1
# 888.0       1
# 96.0        1
# 712.0       1
# 54.0        1
# 536.0       1
# 256.0       1
# 41.0        1
# 1328.0      1
# 1632.0      1
# 143.0       1
# 32.0        1
# 88.0        1
# 900.0       1
# 496.0       1
# 1392.0      1
# 190.0       1
# 94.0        1
# 27.0        1
# 696.0       1
# 194.0       1
# 2.0         1
# 128.0       1
# 1225.0      1
# 181.0       1
# 772.0       1
# 987.0       1
# 863.0       1
# 557.0       1
# 1249.0      1
# 783.0       1
# 953.0       1
# 751.0       1
# 1558.0      1
# 725.0       1
# 807.0       1
# 689.0       1
# 1030.0      1
# 1178.0      1
# 1170.0      1
# 331.0       1
# 944.0       1
# 984.0       1
# 488.0       1
# 186.0       1
# 1080.0      1
# 1440.0      1
# 242.0       1
# 78.0        1
# 952.0       1
# 1012.0      1
# 296.0       1
# 328.0       1
# 424.0       1
# 236.0       1
# 376.0       1
# 526.0       1
# 968.0       1
# 445.0       1
# 1571.0      1
# 443.0       1
# 1163.0      1
# 1606.0      1
# 567.0       1
# 909.0       1
# 895.0       1
# 1013.0      1
# 1277.0      1
# 63.0        1
# 848.0       1
# 70.0        1
# 688.0       1
# 472.0       1
# 661.0       1
# Name: BsmtFin SF 1, dtype: int64

# %%
df_train['BsmtFin SF 1'].isnull().sum()
# Out:
# 1

# %%
#https://datatofish.com/rows-with-nan-pandas-dataframe/
# to troubleshoot showing just the np.nan row

df_train[df_train['BsmtFin SF 1'].isna()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1327         TA      PConc        0.0        0.0              0
#
#       BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 1327               0           NaN            NaN           NaN          NaN
#
#       Total Bsmt SF Heating Heating QC Central Air Electrical  1st Flr SF  \
# 1327            NaN    GasA         TA           Y      FuseA         896
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 1327           0                0          896             NaN
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 1327             NaN          1          0              2              1
#
#      Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu  \
# 1327           TA              4        Typ           0          NaN
#
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 1327      Detchd         1946.0           Unf          1.0        280.0
#
#      Garage Qual Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  \
# 1327          TA          TA           Y             0              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  Fence  \
# 1327               0           0             0          0     NaN  MnPrv
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice  \
# 1327          NaN         0        4     2008     ConLD      79000
#
#       lot_area_frontage
# 1327           0.016667

# %%
df_train['BsmtFin SF 1'].fillna(0, inplace = True)

# %% [markdown]
# ### BsmtFin Type 2

# %%
df_train['BsmtFin Type 2'].isnull().sum()
# Out:
# 56

# %%
df_train['BsmtFin Type 2'].fillna('None', inplace = True)

# %%
df_train['BsmtFin Type 2'] = df_train['BsmtFin Type 2'].map(bsmt_fin_dict)

# %% [markdown]
# ### BsmtFin SF 2

# %%
df_train[df_train['BsmtFin SF 2'].isna()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1327         TA      PConc        0.0        0.0              0
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 1327               0           0.0               0           NaN          NaN
#
#       Total Bsmt SF Heating Heating QC Central Air Electrical  1st Flr SF  \
# 1327            NaN    GasA         TA           Y      FuseA         896
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 1327           0                0          896             NaN
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 1327             NaN          1          0              2              1
#
#      Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu  \
# 1327           TA              4        Typ           0          NaN
#
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 1327      Detchd         1946.0           Unf          1.0        280.0
#
#      Garage Qual Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  \
# 1327          TA          TA           Y             0              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  Fence  \
# 1327               0           0             0          0     NaN  MnPrv
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice  \
# 1327          NaN         0        4     2008     ConLD      79000
#
#       lot_area_frontage
# 1327           0.016667

# %%
df_train['BsmtFin SF 2'].fillna(0, inplace = True)

# %% [markdown]
# ### Bsmt Unf SF

# %%
df_train[df_train['Bsmt Unf SF'].isna()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1327         TA      PConc        0.0        0.0              0
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 1327               0           0.0               0           0.0          NaN
#
#       Total Bsmt SF Heating Heating QC Central Air Electrical  1st Flr SF  \
# 1327            NaN    GasA         TA           Y      FuseA         896
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 1327           0                0          896             NaN
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 1327             NaN          1          0              2              1
#
#      Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu  \
# 1327           TA              4        Typ           0          NaN
#
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 1327      Detchd         1946.0           Unf          1.0        280.0
#
#      Garage Qual Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  \
# 1327          TA          TA           Y             0              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  Fence  \
# 1327               0           0             0          0     NaN  MnPrv
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice  \
# 1327          NaN         0        4     2008     ConLD      79000
#
#       lot_area_frontage
# 1327           0.016667

# %%
df_train['Bsmt Unf SF'].fillna(0, inplace = True)

# %% [markdown]
# ### Total Bsmt SF

# %%
df_train[df_train['Total Bsmt SF'].isna()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 1327         TA      PConc        0.0        0.0              0
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 1327               0           0.0               0           0.0          NaN
#
#       Total Bsmt SF Heating Heating QC Central Air Electrical  1st Flr SF  \
# 1327            NaN    GasA         TA           Y      FuseA         896
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 1327           0                0          896             NaN
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 1327             NaN          1          0              2              1
#
#      Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu  \
# 1327           TA              4        Typ           0          NaN
#
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 1327      Detchd         1946.0           Unf          1.0        280.0
#
#      Garage Qual Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  \
# 1327          TA          TA           Y             0              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  Fence  \
# 1327               0           0             0          0     NaN  MnPrv
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice  \
# 1327          NaN         0        4     2008     ConLD      79000
#
#       lot_area_frontage
# 1327           0.016667

# %%
df_train['Total Bsmt SF'].fillna(0, inplace = True)

# %% [markdown]
# ### Bsmt Full Bath

# %%
df_train[df_train['Bsmt Full Bath'].isna()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 616    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 616              7        1959            1996      Gable   CompShg
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 616       Plywood      Plywood         None           0.0         TA
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 616          TA       Slab        0.0        0.0              0
# 1327         TA      PConc        0.0        0.0              0
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 616                0           0.0               0           0.0          0.0
# 1327               0           0.0               0           0.0          0.0
#
#       Total Bsmt SF Heating Heating QC Central Air Electrical  1st Flr SF  \
# 616             0.0    GasA         TA           Y      SBrkr        3820
# 1327            0.0    GasA         TA           Y      FuseA         896
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 616            0                0         3820             NaN
# 1327           0                0          896             NaN
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 616              NaN          3          1              5              1
# 1327             NaN          1          0              2              1
#
#      Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu  \
# 616            Ex             11        Typ           2           Gd
# 1327           TA              4        Typ           0          NaN
#
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 616       Attchd         1959.0           Unf          2.0        624.0
# 1327      Detchd         1946.0           Unf          1.0        280.0
#
#      Garage Qual Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  \
# 616           TA          TA           Y             0            372
# 1327          TA          TA           Y             0              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  Fence  \
# 616                0           0             0          0     NaN    NaN
# 1327               0           0             0          0     NaN  MnPrv
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice  \
# 616           NaN         0        7     2008       WD      284700
# 1327          NaN         0        4     2008     ConLD      79000
#
#       lot_area_frontage
# 616            0.002617
# 1327           0.016667

# %%
df_train['Bsmt Full Bath'].fillna(0, inplace = True)

# %% [markdown]
# ### Bsmt Half Bath

# %%
df_train[df_train['Bsmt Half Bath'].isna()]
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      Alley Lot Shape Land Contour Utilities Lot Config Land Slope  \
# 616    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      Neighborhood Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# 616              7        1959            1996      Gable   CompShg
# 1327             7        1946            1950      Gable   CompShg
#
#      Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual  \
# 616       Plywood      Plywood         None           0.0         TA
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      Exter Cond Foundation  Bsmt Qual  Bsmt Cond  Bsmt Exposure  \
# 616          TA       Slab        0.0        0.0              0
# 1327         TA      PConc        0.0        0.0              0
#
#       BsmtFin Type 1  BsmtFin SF 1  BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# 616                0           0.0               0           0.0          0.0
# 1327               0           0.0               0           0.0          0.0
#
#       Total Bsmt SF Heating Heating QC Central Air Electrical  1st Flr SF  \
# 616             0.0    GasA         TA           Y      SBrkr        3820
# 1327            0.0    GasA         TA           Y      FuseA         896
#
#       2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 616            0                0         3820             0.0
# 1327           0                0          896             0.0
#
#       Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 616              NaN          3          1              5              1
# 1327             NaN          1          0              2              1
#
#      Kitchen Qual  TotRms AbvGrd Functional  Fireplaces Fireplace Qu  \
# 616            Ex             11        Typ           2           Gd
# 1327           TA              4        Typ           0          NaN
#
#      Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 616       Attchd         1959.0           Unf          2.0        624.0
# 1327      Detchd         1946.0           Unf          1.0        280.0
#
#      Garage Qual Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  \
# 616           TA          TA           Y             0            372
# 1327          TA          TA           Y             0              0
#
#       Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  Fence  \
# 616                0           0             0          0     NaN    NaN
# 1327               0           0             0          0     NaN  MnPrv
#
#      Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice  \
# 616           NaN         0        7     2008       WD      284700
# 1327          NaN         0        4     2008     ConLD      79000
#
#       lot_area_frontage
# 616            0.002617
# 1327           0.016667

# %%
df_train['Bsmt Full Bath'].fillna(0, inplace = True)

# %% [markdown]
# ### Pool QC Column

# %%
df_train['Pool QC'].value_counts()
# Out:
# Gd    4
# Fa    2
# TA    2
# Ex    1
# Name: Pool QC, dtype: int64

# %%
df_train['Pool QC'].isnull().mean()
# Out:
# 0.9956118966357874

# %% [markdown]
# The Column 'Pool QC' has 9 total entries. The remainder null values I assume means they do not have pools. Since 99.5% of homes do **not** have a pool I will not use the column as a feature.

# %% [markdown]
# ### Fence

# %%
df_train['Fence'].value_counts()
# Out:
# MnPrv    227
# GdPrv     83
# GdWo      80
# MnWw      10
# Name: Fence, dtype: int64

# %% [markdown]
# The column 'Fence' would have to be changed to values 1-5 with NaN changed to a value to 0 in order to represent no fence.

# %% [markdown]
# ### Misc Feature

# %%
df_train['Misc Feature'].value_counts()
# Out:
# Shed    56
# Gar2     4
# Othr     3
# Elev     1
# TenC     1
# Name: Misc Feature, dtype: int64

# %% [markdown]
# The column Misc Feature represents features such as a second garage, shed, or elevator. If this column is used for predicting, then all 0's after one-hot encoding would represent no Misc features.

# %% [markdown]
# ## Changing Obj type to numericals
#
# In order to perform analysis, the object type columns will need to be converted into numerical values.

# %%
df_train.dtypes.value_counts()
# Out:
# object     39
# int64      29
# float64    14
# dtype: int64

# %% [markdown]
# There are 42 columns that need to either be converted into numericals or dropped in order to be used in analysis.

# %% [markdown]
# ## Potential Feature Columns:

# %%
[i for i in df_train.columns if 'Qual' in i]
# Out:
# ['Overall Qual',
#  'Exter Qual',
#  'Bsmt Qual',
#  'Low Qual Fin SF',
#  'Kitchen Qual',
#  'Garage Qual']

# %% [markdown]
# The columns: **'Overall Qual',
#  'Exter Qual',
#  'Bsmt Qual',
#  'Low Qual Fin SF',
#  'Kitchen Qual',
#  'Garage Qual'** are ordinal but will have to be converted into numerical values.
#
#  As my analysis focuses on finding a home, upgrading or updating, and then repricing; finding a correlation between these categories and the overall price is extremely important.

# %%
df_train['Yr Sold'].value_counts()
# Out:
# 2007    498
# 2009    446
# 2006    438
# 2008    435
# 2010    234
# Name: Yr Sold, dtype: int64

# %% [markdown]
# Something to keep in mind is the recession and real estate crash starting in 2008. I'd expect values to be higher in 2007 than the following years.
